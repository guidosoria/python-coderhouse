# %% [markdown]
# # Nuestro Primer View
# ##### Lo primero que tendremos que hacer es crear un archivo para esta nueva vista o view
# ##### Usualmente se suele llamar __view.py__ y deberemos crearlo en la carpeta del proyecto donde se encuentra \_\_init\_\_, wsgi etc

# %% [markdown]
# ### Importar Http Response
# ##### En nuestro archivo views.py importaremos los elementos de "Response" de la siguiente manera:
# ##### __from django.http import HttpResponse__
# ![image.png](attachment:image.png)
# ##### Luego iniciamos creando nuestra primer vista, por medio de un método que recibe como parámetro la request y nos da por resultado un response:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Indicar cual será la URL que nos llevará a esa vista - urls.py
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Agregar otra view
# ![image.png](attachment:image.png)
