# %% [markdown]
# # Bucles y Condicionales en nuestros templates HTML
#
# #### Es posible realizar estructuras de bucle y condicionales en nuestros templates. La forma de hacerlo es la siguiente:
#
# #### Supongamos que a nuestro template, en el contexto le pasamos una lista:
# ![image.png](attachment:image.png)
#
# #### Podemos hace un bucle "for" en nuestro template para iterar sobre ella, y también añadir condicionales:
# ![image-2.png](attachment:image-2.png)
